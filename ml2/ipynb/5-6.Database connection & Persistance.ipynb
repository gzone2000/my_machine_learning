# %% [markdown]
# # 5-6 Database connection & Persistance

# %%
import pandas as pd

# %% [markdown]
# ### Load database
# #### Example from
# - https://www.dataquest.io/blog/python-pandas-databases/

# %% [markdown]
# ### sqlite3 설치
# - !conda install pymysql -y

# %% [markdown]
# ### 아래 파일을 ./data 폴더에 업로드 하기
# - flights.db
#
# ### flights.db 문제가 있어 아래 sqlite3 실습 안됨

# %%
import sqlite3 #pymysql <- 설치

conn = sqlite3.connect("./data/flights.db")
cur = conn.cursor()
cur

# %%
#cur.execute("select * from airlines limit 5;")
cur.execute("select * from routes limit 5;")
results = cur.fetchall()
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-e7dee50cf067> in <module>
#       1 #cur.execute("select * from airlines limit 5;")
# ----> 2 cur.execute("select * from routes limit 5;")
#       3 results = cur.fetchall()
#       4 results
#
# OperationalError: no such table: routes

# %% [markdown]
# #### Data loading using pandas from DB

# %%
df_airplines = pd.read_sql_query("select * from airlines;", conn)
df_airplines

# %%
df_airports = pd.read_sql_query("select * from airports;", conn)
df_routes = pd.read_sql_query("select * from routes;", conn)

# %%
df_airplines

# %%
df_airports.head()

# %%
df_routes.head()

# %% [markdown]
# ### Pandas persistence
# #### install
# - conda install openpyxl
# - conda install XlsxWriter
# - see more http://xlsxwriter.readthedocs.io/working_with_pandas.html

# %%
import pandas as pd

# %%
df_routes = pd.read_excel("./data/excel-comp-data.xlsx")
df_routes
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
writer = pd.ExcelWriter('./data/df_routes.xlsx', engine='xlsxwriter')   # ./data/df_routes.xlsx 파일 생성
df_routes.to_excel(writer, sheet_name='Sheet1')

# %%
df_routes.to_pickle("./data/df_routes.pickle")

# %%
df_routes_pickle = pd.read_pickle("./data/df_routes.pickle")
df_routes_pickle.head()
# Out:
#    account                         name                                street  \
# 0   211829   Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 1   320563               Walter-Trantow                     1311 Alvis Tunnel
# 2   648336   Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231
# 3   109996  D'Amore, Gleichner and Bode           155 Fadel Crescent Apt. 144
# 4   121213                Bauch-Goldner                   7274 Marissa Common
#
#               city          state  postal-code     Jan     Feb    Mar
# 0       New Jaycob          Texas        28752   10000   62000  35000
# 1    Port Khadijah  NorthCarolina        38365   95000   45000  35000
# 2   New Lilianland           Iowa        76517   91000  120000  35000
# 3       Hyattburgh          Maine        46021   45000  120000  10000
# 4  Shanahanchester     California        49681  162000  120000  35000

# %%
df_routes_pickle.describe()
# Out:
#              account   postal-code            Jan            Feb  \
# count      15.000000     15.000000      15.000000      15.000000
# mean   236509.466667  46400.600000   97466.666667  100466.666667
# std    128420.806565  17343.118919   51159.228558   34450.516618
# min    109996.000000  18008.000000   10000.000000   10000.000000
# 25%    175142.500000  31667.000000   58500.000000   95000.000000
# 50%    212303.000000  46308.000000   91000.000000  120000.000000
# 75%    255561.500000  58123.000000  150000.000000  120000.000000
# max    648336.000000  76517.000000  162000.000000  120000.000000
#
#                  Mar
# count      15.000000
# mean    47800.000000
# std     34996.326338
# min     10000.000000
# 25%     35000.000000
# 50%     35000.000000
# 75%     45000.000000
# max    162000.000000
