# %%
# ======================================================================
# There are 5 questions in this test with increasing difficulty from 1-5
# Please note that the weight of the grade for the question is relative
# to its difficulty. So your Category 1 question will score much less
# than your Category 5 question.
# ======================================================================
#
# Basic Datasets question
#
# For this task you will train a classifier for Iris flowers using the Iris dataset
# The final layer in your neural network should look like: tf.keras.layers.Dense(3, activation=tf.nn.softmax)
# The input layer will expect data in the shape (4,)
# We've given you some starter code for preprocessing the data
# You'll need to implement the preprocess function for data.map

# =================================================== #
# =================================================== #
# ====== 모델링 할 때는 포함, 시험 볼때는 제거 ====== #
# 텐서플로우 버전 충돌로 인하여 
# 반드시 tensorflow 버전을 2.1.0 버전 설치 후 
# 모델작업 진행 해주셔야 합니다.
# 시험보실 때는 아래 
# !pip install tensorflow==2.1.0 명령어 필요 없습니다
# 텐서플로우 2.1.0 버전 재설치 코드
# !pip install tensorflow==2.1.0

# ====== 모델링 할 때는 포함, 시험 볼때는 제거 ====== #
# =================================================== #

# =========== 합격 기준 가이드라인 공유 ============= #
# val_loss 기준에 맞춰 주시는 것이 훨씬 더 중요 #
# val_loss 보다 조금 높아도 상관없음. (언저리까지 OK) #
# =================================================== #
# 문제명: Category 2 - iris
# val_loss: 0.14
# val_acc: 0.93
# =================================================== #
# =================================================== #


import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

#data = tfds.load("iris", split=tfds.Split.TRAIN.subsplit(tfds.percent[:80]))
train_dataset = tfds.load('iris', split='train[:80%]')
valid_dataset = tfds.load('iris', split='train[80%:]')

def preprocess(data):
    # YOUR CODE HERE
    # Should return features and one-hot encoded labels
    x = data['features']
    y = data['label']
    y = tf.one_hot(y, 3)
    return x, y

def solution_model():
    batch_size=10
    #train_dataset = data.map(preprocess).batch(10)
    train_data = train_dataset.map(preprocess).batch(batch_size)
    valid_data = valid_dataset.map(preprocess).batch(batch_size)

    # YOUR CODE TO TRAIN A MODEL HERE
    model = tf.keras.models.Sequential([
        Dense(512, activation='relu', input_shape=(4,)),
        BatchNormalization(),
        Dense(256, activation='relu'),
        BatchNormalization(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dense(64, activation='relu'),
        BatchNormalization(),
        Dense(32, activation='relu'),
        BatchNormalization(),
        Dense(3, activation='softmax'),
    ])

    model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['acc'],
                  )
    checkpoint_path = 'my_checkpint.ckpt'
    checkpoint = ModelCheckpoint(checkpoint_path,
                                 save_weights_only=True,
                                 save_best_only=True,
                                 monitor='val_loss',
                                 verbose=1,
                                 )
    model.fit(train_data,
              validation_data=(valid_data),
              epochs=30,
              callbacks=[checkpoint],
              )
    
    model.load_weights(checkpoint_path)

    return model


# Note that you'll need to save your model as a .h5 like this
# This .h5 will be uploaded to the testing infrastructure
# and a score will be returned to you
if __name__ == '__main__':
    model = solution_model()
    model.save("TF2-iris.h5")
# Out:
# Collecting tensorflow==2.1.0
#   Downloading https://files.pythonhosted.org/packages/85/d4/c0cd1057b331bc38b65478302114194bd8e1b9c2bbc06e300935c0e93d90/tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 29kB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.1.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (3.3.0)
# Collecting keras-applications>=1.0.8
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 7.6MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.12.1)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 53.9MB/s
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.18.5)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 61.7MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.31.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.35.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.4.1)
# Collecting gast==0.2.2
#   Downloading https://files.pythonhosted.org/packages/4e/35/11749bf99b2d4e3cceb4d55ca22590b0d7c2c62b9de38ac4a4a7f4687421/gast-0.2.2.tar.gz
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.8.1)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.8.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (3.12.4)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.15.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.1.0) (2.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.17.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (49.6.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.2.8)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.7.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.10)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.1.0)
# Building wheels for collected packages: gast
#   Building wheel for gast (setup.py) ... done
#   Created wheel for gast: filename=gast-0.2.2-cp36-none-any.whl size=7542 sha256=230aa167407246d18864926816cc56a594245dae11d8bc88220a5fe2a636d7fb
#   Stored in directory: /root/.cache/pip/wheels/5c/2e/7e/a1d4d4fcebe6c381f378ce7743a3ced3699feb89bcfbdadadd
# Successfully built gast
# ERROR: tensorflow-probability 0.11.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Installing collected packages: keras-applications, tensorboard, tensorflow-estimator, gast, tensorflow
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: gast 0.3.3
#     Uninstalling gast-0.3.3:
#       Successfully uninstalled gast-0.3.3
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# Successfully installed gast-0.2.2 keras-applications-1.0.8 tensorboard-2.1.1 tensorflow-2.1.0 tensorflow-estimator-2.1.0
# Downloading and preparing dataset iris/2.0.0 (download: 4.44 KiB, generated: Unknown size, total: 4.44 KiB) to /root/tensorflow_datasets/iris/2.0.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# /usr/local/lib/python3.6/dist-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /root/tensorflow_datasets/iris/2.0.0.incompleteRH93K9/iris-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=150.0), HTML(value='')))
# Dataset iris downloaded and prepared to /root/tensorflow_datasets/iris/2.0.0. Subsequent calls will reuse this data.
# Epoch 1/30
#      12/Unknown - 2s 208ms/step - loss: 0.5337 - acc: 0.8000
# Epoch 00001: val_loss improved from inf to 1.04216, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 3s 228ms/step - loss: 0.5337 - acc: 0.8000 - val_loss: 1.0422 - val_acc: 0.3333
# Epoch 2/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.1577 - acc: 0.9500
# Epoch 00002: val_loss did not improve from 1.04216
# 12/12 [==============================] - 0s 11ms/step - loss: 0.1541 - acc: 0.9500 - val_loss: 1.0825 - val_acc: 0.3333
# Epoch 3/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0665 - acc: 0.9909
# Epoch 00003: val_loss did not improve from 1.04216
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0736 - acc: 0.9833 - val_loss: 1.0845 - val_acc: 0.3333
# Epoch 4/30
#  1/12 [=>............................] - ETA: 0s - loss: 0.0191 - acc: 1.0000
# Epoch 00004: val_loss improved from 1.04216 to 1.02633, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0427 - acc: 1.0000 - val_loss: 1.0263 - val_acc: 0.3333
# Epoch 5/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0269 - acc: 1.0000
# Epoch 00005: val_loss improved from 1.02633 to 0.97973, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0276 - acc: 1.0000 - val_loss: 0.9797 - val_acc: 0.4000
# Epoch 6/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0208 - acc: 1.0000
# Epoch 00006: val_loss improved from 0.97973 to 0.92721, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0210 - acc: 1.0000 - val_loss: 0.9272 - val_acc: 0.4333
# Epoch 7/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0163 - acc: 1.0000
# Epoch 00007: val_loss improved from 0.92721 to 0.87556, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0169 - acc: 1.0000 - val_loss: 0.8756 - val_acc: 0.5000
# Epoch 8/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0146 - acc: 1.0000
# Epoch 00008: val_loss improved from 0.87556 to 0.83615, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0145 - acc: 1.0000 - val_loss: 0.8361 - val_acc: 0.6000
# Epoch 9/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0122 - acc: 1.0000
# Epoch 00009: val_loss improved from 0.83615 to 0.79294, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 0.7929 - val_acc: 0.6333
# Epoch 10/30
#  1/12 [=>............................] - ETA: 0s - loss: 0.0046 - acc: 1.0000
# Epoch 00010: val_loss improved from 0.79294 to 0.75355, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0112 - acc: 1.0000 - val_loss: 0.7535 - val_acc: 0.6667
# Epoch 11/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0098 - acc: 1.0000
# Epoch 00011: val_loss improved from 0.75355 to 0.71947, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0100 - acc: 1.0000 - val_loss: 0.7195 - val_acc: 0.6667
# Epoch 12/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0088 - acc: 1.0000
# Epoch 00012: val_loss improved from 0.71947 to 0.68618, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0091 - acc: 1.0000 - val_loss: 0.6862 - val_acc: 0.6333
# Epoch 13/30
#  7/12 [================>.............] - ETA: 0s - loss: 0.0083 - acc: 1.0000
# Epoch 00013: val_loss improved from 0.68618 to 0.65497, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0082 - acc: 1.0000 - val_loss: 0.6550 - val_acc: 0.6333
# Epoch 14/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0072 - acc: 1.0000
# Epoch 00014: val_loss improved from 0.65497 to 0.62983, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0075 - acc: 1.0000 - val_loss: 0.6298 - val_acc: 0.6333
# Epoch 15/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0066 - acc: 1.0000
# Epoch 00015: val_loss improved from 0.62983 to 0.60468, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0068 - acc: 1.0000 - val_loss: 0.6047 - val_acc: 0.6333
# Epoch 16/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0061 - acc: 1.0000
# Epoch 00016: val_loss improved from 0.60468 to 0.57947, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.5795 - val_acc: 0.6333
# Epoch 17/30
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0057 - acc: 1.0000
# Epoch 00017: val_loss improved from 0.57947 to 0.55096, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.5510 - val_acc: 0.6667
# Epoch 18/30
#  9/12 [=====================>........] - ETA: 0s - loss: 0.0053 - acc: 1.0000
# Epoch 00018: val_loss improved from 0.55096 to 0.51602, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0054 - acc: 1.0000 - val_loss: 0.5160 - val_acc: 0.6667
# Epoch 19/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0049 - acc: 1.0000
# Epoch 00019: val_loss improved from 0.51602 to 0.47465, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.4746 - val_acc: 0.6667
# Epoch 20/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0048 - acc: 1.0000
# Epoch 00020: val_loss improved from 0.47465 to 0.42930, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0048 - acc: 1.0000 - val_loss: 0.4293 - val_acc: 0.7000
# Epoch 21/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0046 - acc: 1.0000
# Epoch 00021: val_loss improved from 0.42930 to 0.37890, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.3789 - val_acc: 0.8000
# Epoch 22/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0041 - acc: 1.0000
# Epoch 00022: val_loss improved from 0.37890 to 0.32419, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0043 - acc: 1.0000 - val_loss: 0.3242 - val_acc: 0.9000
# Epoch 23/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0039 - acc: 1.0000
# Epoch 00023: val_loss improved from 0.32419 to 0.26791, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0040 - acc: 1.0000 - val_loss: 0.2679 - val_acc: 0.9000
# Epoch 24/30
#  8/12 [===================>..........] - ETA: 0s - loss: 0.0038 - acc: 1.0000
# Epoch 00024: val_loss improved from 0.26791 to 0.22128, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0038 - acc: 1.0000 - val_loss: 0.2213 - val_acc: 0.9333
# Epoch 25/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0037 - acc: 1.0000
# Epoch 00025: val_loss improved from 0.22128 to 0.18179, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0036 - acc: 1.0000 - val_loss: 0.1818 - val_acc: 0.9333
# Epoch 26/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0035 - acc: 1.0000
# Epoch 00026: val_loss improved from 0.18179 to 0.15033, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0035 - acc: 1.0000 - val_loss: 0.1503 - val_acc: 0.9667
# Epoch 27/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0032 - acc: 1.0000
# Epoch 00027: val_loss improved from 0.15033 to 0.12520, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 0.1252 - val_acc: 0.9667
# Epoch 28/30
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0032 - acc: 1.0000
# Epoch 00028: val_loss improved from 0.12520 to 0.10863, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 0.1086 - val_acc: 0.9333
# Epoch 29/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0029 - acc: 1.0000
# Epoch 00029: val_loss improved from 0.10863 to 0.09772, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0030 - acc: 1.0000 - val_loss: 0.0977 - val_acc: 0.9333
# Epoch 30/30
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0028 - acc: 1.0000
# Epoch 00030: val_loss improved from 0.09772 to 0.09213, saving model to my_checkpint.ckpt
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.0921 - val_acc: 0.9667
